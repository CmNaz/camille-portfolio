# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !pip install websocket-client
# !pip install python-binance
# Out:
# Mounted at /content/gdrive
# ...
#      |████████████████████████████████| 61kB 2.9MB/s
# ...
#      |████████████████████████████████| 184kB 6.9MB/s
# ...
#      |████████████████████████████████| 501kB 42.9MB/s
# ...
#      |████████████████████████████████| 3.2MB 34.6MB/s
# ...
#      |████████████████████████████████| 61kB 6.1MB/s
# ...
#      |████████████████████████████████| 3.1MB 30.5MB/s
# ...
#      |████████████████████████████████| 286kB 45.2MB/s
# ...
#      |████████████████████████████████| 81kB 7.8MB/s
# ...
#      |████████████████████████████████| 256kB 41.1MB/s
# ...

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/ACTUAL\ COPY/nanimo/sol2/quicKeshi.py
while True:pass
# Out:
# Streaming output truncated to the last 5000 lines.
# Open price: 59559.79000000 Closing price: 59585.26000000
# Open price: 59597.48000000 Closing price: 59585.26000000
# [BTCUSDT] received message
# Open price: 59559.79000000 Closing price: 59585.26000000
# [BTCUSDT] received hourly message
# Open price: 59597.48000000 Closing price: 59585.26000000
# [BTCUSDT] received message
# Open price: 59559.79000000 Closing price: 59585.98000000
# [BTCUSDT] received hourly message
# Open price: 59597.48000000 Closing price: 59585.98000000
# [BTCUSDT] received message
# Open price: 59559.79000000 Closing price: 59585.99000000
# [BTCUSDT] received hourly message
# Open price: 59597.48000000 Closing price: 59585.99000000
# [BTCUSDT] received message
# Open price: 59559.79000000 Closing price: 59590.57000000
# [BTCUSDT] received hourly message
# Open price: 59597.48000000 Closing price: 59590.57000000
# [BTCUSDT] received hourly message
# Open price: 59597.48000000 Closing price: 59552.43000000
# ...

# %%
while True:pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-534b7a74019f> in <module>()
# ----> 1 while True:pass
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-534b7a74019f> in <module>()
# ----> 1 while True:pass
#
# KeyboardInterrupt:
